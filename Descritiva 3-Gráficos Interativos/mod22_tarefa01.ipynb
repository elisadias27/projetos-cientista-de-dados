# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %%
from pandas_datareader import data as web

import plotly.express as px
from plotly import graph_objects

import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
# %%time
ativos = ['DIS', 'NFLX', 'AAPL']
data_ini = '13/12/2021'

companies = web.get_data_yahoo(ativos, start=data_ini)
companies.head()
# Out:
# C:\Users\WorkStation\anaconda3\lib\site-packages\pandas_datareader\_utils.py:33: UserWarning:
#
# Parsing '13/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# Wall time: 4 s
# Attributes   Adj Close                               Close              \
# Symbols            DIS        NFLX        AAPL         DIS        NFLX
# Date
# 2021-12-13  150.429993  604.559998  174.725937  150.429993  604.559998
# 2021-12-14  149.100006  597.989990  173.324066  149.100006  597.989990
# 2021-12-15  150.399994  605.039978  178.265396  150.399994  605.039978
# 2021-12-16  148.750000  591.059998  171.266006  148.750000  591.059998
# 2021-12-17  148.759995  586.729980  170.152466  148.759995  586.729980
#
# Attributes                    High                                 Low  \
# Symbols           AAPL         DIS        NFLX        AAPL         DIS
# Date
# 2021-12-13  175.740005  152.500000  612.640015  182.130005  149.289993
# 2021-12-14  174.330002  151.619995  602.289978  177.740005  148.520004
# 2021-12-15  179.300003  150.919998  605.690002  179.500000  147.350006
# 2021-12-16  172.259995  152.059998  602.830017  181.139999  148.580002
# 2021-12-17  171.139999  149.839996  593.250000  173.470001  146.570007
#
# Attributes                                Open                          \
# Symbols           NFLX        AAPL         DIS        NFLX        AAPL
# Date
# 2021-12-13  599.520020  175.529999  152.119995  612.000000  181.119995
# 2021-12-14  588.130005  172.210007  149.259995  598.710022  175.250000
# 2021-12-15  584.510010  172.309998  148.759995  598.179993  175.110001
# 2021-12-16  588.000000  170.750000  151.350006  597.090027  179.279999
# 2021-12-17  581.739990  169.690002  148.509995  591.609985  169.929993
#
# Attributes      Volume
# Symbols            DIS       NFLX         AAPL
# Date
# 2021-12-13  10195800.0  2517900.0  153237000.0
# 2021-12-14  10872000.0  2984500.0  139380400.0
# 2021-12-15  12231500.0  2866200.0  131063300.0
# 2021-12-16  11145600.0  3143200.0  150185800.0
# 2021-12-17  13785000.0  4386900.0  195432700.0

# %%
companies.to_csv('companies.csv')

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
max_volume = companies.Volume.max()
min_volume = companies.Volume.min()

# %%
max_volume
# Out:
# Symbols
# DIS      70273500.0
# NFLX    133387500.0
# AAPL    195432700.0
# dtype: float64

# %%
min_volume
# Out:
# Symbols
# DIS      2291789.0
# NFLX     1287200.0
# AAPL    13602320.0
# dtype: float64

# %%
tabela = companies['Adj Close'].stack().reset_index()
tabela.columns = ['data', 'ativo', 'volume']

tabela.head()
# Out:
#         data ativo      volume
# 0 2021-12-13   DIS  150.429993
# 1 2021-12-13  NFLX  604.559998
# 2 2021-12-13  AAPL  174.725937
# 3 2021-12-14   DIS  149.100006
# 4 2021-12-14  NFLX  597.989990

# %%
fig = px.line(tabela, x="data", y="volume", color='ativo', template='simple_white')
fig.show()
# Out:
# <div>                            <div id="a727253a-6245-4345-884f-7cb3c57a65d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a727253a-6245-4345-884f-7cb3c57a65d7")) {                    Plotly.newPlot(                        "a727253a-6245-4345-884f-7cb3c57a65d7",                        [{"hovertemplate":"ativo=DIS<br>data=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"DIS","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"DIS","orientation":"v","showlegend":true,"x":["2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00","2022-07-01T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-11T00:00:00","2022-07-12T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","20 ...
